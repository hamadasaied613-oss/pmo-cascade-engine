# %% [markdown]
# # INPUT: FAR Analysis---**Output:** FAR Analysis (Domain 04)**Standards:** Floor Area Ratio Calculation**ISO:** ISO 21500:2012## PurposeCalculate and verify Floor Area Ratio compliance.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Plot Area + Zoning FAR -> **THIS INPUT** -> **ACTIVITY:** FAR Calculation -> **OUTPUT:** FAR Analysis

# %%
# INPUT: FAR Analysisprint("=" * 70)print("INPUT: FAR Analysis")print("Output: Domain 04 - FAR Analysis")print("=" * 70)print("")inputs = [    ("Plot Area (m2)", "[REF] From Site Analysis", "D02-INPUT_01", "Site Analysis"),    ("FAR Maximum Allowed", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("Proposed GFA (m2)", "[ABS] Architect proposes", "Architect", "FAR Analysis"),    ("Basement Area (m2)", "[ABS] Architect proposes", "Architect", "FAR Analysis"),    ("Void Area (m2)", "[ABS] Architect proposes", "Architect", "FAR Analysis"),    ("Exempt Area (m2)", "[ABS] Zoning exemptions", "ACT-Zoning", "FAR Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Net FAR: CALCULATED (GFA/Plot Area)")print("  - FAR Status: COMPLIANT/NON-COMPLIANT")print("  - Available GFA: CALCULATED")

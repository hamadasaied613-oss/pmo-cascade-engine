# %% [markdown]
# # INPUT: Noise Zoning Compliance---**Output:** Noise Zoning Compliance (DOMAIN 04 ZONING)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Noise Zoning Compliance.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Noise Zoning Compliance

# %%
# INPUT: Noise Zoning Complianceprint("=" * 70)print("INPUT: Noise Zoning Compliance")print("Output: DOMAIN 04 ZONING - Noise Zoning Compliance")print("=" * 70)print("")inputs = [    ("Noise Standards", "[ABS] Kahramaa data", "Kahramaa", "Noise Zoning"),    ("Measured Levels", "[ABS] Noise survey", "ENV Consultant", "Noise Zoning"),    ("Mitigation Measures", "[ABS] Consultant proposes", "Consultant", "Noise Zoning"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Noise Zoning"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Parking Analysis---**Output:** Parking Analysis (Domain 04)**Standards:** Municipality Parking Requirements**ISO:** ISO 21500:2012## PurposeCalculate parking requirements and verify compliance.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Building Program + Zoning Parking -> **THIS INPUT** -> **ACTIVITY:** Parking Calculation -> **OUTPUT:** Parking Analysis

# %%
# INPUT: Parking Analysisprint("=" * 70)print("INPUT: Parking Analysis")print("Output: Domain 04 - Parking Analysis")print("=" * 70)print("")inputs = [    ("Building Use Type", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("GFA (m2)", "[REF] From FAR Analysis", "D04-INPUT_02", "FAR Analysis"),    ("Parking Ratio Required", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("Proposed Parking Spaces", "[ABS] Architect proposes", "Architect", "Parking Analysis"),    ("Visitor Parking Spaces", "[ABS] Architect proposes", "Architect", "Parking Analysis"),    ("Disabled Parking Spaces", "[ABS] Accessibility code", "STD-Accessibility", "Accessibility"),    ("EV Charging Points", "[ABS] Sustainability target", "STD-Sustainability", "Estidama"),    ("Basement Levels", "[ABS] Architect proposes", "Architect", "Parking Analysis"),    ("Stacking System", "[ABS] Mechanical parking", "STD-Mechanical", "Parking Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Required Spaces: CALCULATED")print("  - Provided Spaces: INPUT")print("  - Compliance Status: COMPLIANT/NON-COMPLIANT")

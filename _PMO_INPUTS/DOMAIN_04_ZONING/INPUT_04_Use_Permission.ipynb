# %% [markdown]
# # INPUT: Use Permission---**Output:** Use Permission (DOMAIN 04 ZONING)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Use Permission.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Use Permission

# %%
# INPUT: Use Permissionprint("=" * 70)print("INPUT: Use Permission")print("Output: DOMAIN 04 ZONING - Use Permission")print("=" * 70)print("")inputs = [    ("Proposed Use", "[ABS] Architect proposes", "Architect", "Use Permission"),    ("Zoning Classification", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("Special Conditions", "[ABS] Municipality", "Municipality", "Use Permission"),    ("Variance Request", "[ABS] Architect proposes", "Architect", "Use Permission"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

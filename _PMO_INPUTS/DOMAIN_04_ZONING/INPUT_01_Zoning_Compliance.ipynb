# %% [markdown]
# # INPUT: Zoning Compliance---**Output:** Zoning Compliance (Domain 04)**Standards:** Local Municipality Zoning | Dubai Building Code**ISO:** ISO 21500:2012## PurposeVerify project compliance with zoning regulations.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Site Analysis + Zoning Maps -> **THIS INPUT** -> **ACTIVITY:** Zoning Analysis -> **OUTPUT:** Zoning Compliance

# %%
# INPUT: Zoning Complianceprint("=" * 70)print("INPUT: Zoning Compliance")print("Output: Domain 04 - Zoning Compliance")print("=" * 70)print("")inputs = [    ("Plot Number", "[REF] From Site Analysis", "D02-INPUT_01", "Site Analysis"),    ("Zoning Classification", "[ABS] Municipality data", "ACT-Municipality", "Zoning Compliance"),    ("Permitted Use", "[ABS] Zoning map", "ACT-Zoning", "Use Permission"),    ("Building Height Limit (m)", "[ABS] Zoning map", "ACT-Zoning", "FAR Analysis"),    ("FAR Maximum", "[ABS] Zoning map", "ACT-Zoning", "FAR Analysis"),    ("Front Setback (m)", "[ABS] Zoning map", "ACT-Zoning", "Zoning Compliance"),    ("Side Setback (m)", "[ABS] Zoning map", "ACT-Zoning", "Zoning Compliance"),    ("Rear Setback (m)", "[ABS] Zoning map", "ACT-Zoning", "Zoning Compliance"),    ("Parking Ratio", "[ABS] Zoning requirements", "ACT-Zoning", "Parking Analysis"),    ("Open Space Ratio", "[ABS] Zoning requirements", "ACT-Zoning", "Landscape Design"),    ("Signage Restrictions", "[ABS] Zoning requirements", "ACT-Zoning", "Zoning Compliance"),    ("Heritage Zone Flag", "[ABS] Heritage survey", "ACT-Heritage", "Zoning Compliance"),    ("Noise Zone Classification", "[ABS] Environmental data", "ACT-Environmental", "Noise Zoning"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Compliance Status: COMPLIANT/NON-COMPLIANT")print("  - Variance Analysis: CALCULATED")print("  - Required Modifications: CALCULATED")

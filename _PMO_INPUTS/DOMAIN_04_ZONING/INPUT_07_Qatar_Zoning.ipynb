# %% [markdown]
# # INPUT: Qatar Zoning Compliance---**Output:** Qatar Zoning Compliance (DOMAIN 04 ZONING)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Qatar Zoning Compliance.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Qatar Zoning Compliance

# %%
# INPUT: Qatar Zoning Complianceprint("=" * 70)print("INPUT: Qatar Zoning Compliance")print("Output: DOMAIN 04 ZONING - Qatar Zoning Compliance")print("=" * 70)print("")inputs = [    ("Qatar Regulations", "[ABS] Ashghal data", "Ashghal", "Qatar Zoning"),    ("Municipality Requirements", "[ABS] Municipality data", "Municipality", "Qatar Zoning"),    ("Special Zone Rules", "[ABS] Zone authority", "Zone Authority", "Qatar Zoning"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Qatar Zoning"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

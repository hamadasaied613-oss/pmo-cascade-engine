# %% [markdown]
# # INPUT: Energy Modeling---**Output:** Energy Modeling (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Energy Modeling.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Energy Modeling

# %%
# INPUT: Energy Modelingprint("=" * 70)print("INPUT: Energy Modeling")print("Output: DOMAIN 12 SUSTAINABILITY - Energy Modeling")print("=" * 70)print("")inputs = [    ("Building Envelope", "[REF] From Design", "D06-INPUT_01", "Design Parameters"),    ("HVAC Systems", "[REF] From MEP", "D06-INPUT_03", "MEP Concept"),    ("Lighting Systems", "[ABS] Engineer specifies", "Engineer", "Energy Modeling"),    ("Energy Target", "[ABS] Client defines", "Client", "Energy Modeling"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

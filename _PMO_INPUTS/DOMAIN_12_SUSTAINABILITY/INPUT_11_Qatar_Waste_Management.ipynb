# %% [markdown]
# # INPUT: Qatar Waste Management Plan---**Output:** Qatar Waste Management Plan (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Qatar Waste Management Plan.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Qatar Waste Management Plan

# %%
# INPUT: Qatar Waste Management Planprint("=" * 70)print("INPUT: Qatar Waste Management Plan")print("Output: DOMAIN 12 SUSTAINABILITY - Qatar Waste Management Plan")print("=" * 70)print("")inputs = [    ("Waste Types", "[ABS] Engineer identifies", "Engineer", "Qatar Waste"),    ("Recycling Targets", "[ABS] Ministry requirements", "Ministry", "Qatar Waste"),    ("Disposal Methods", "[ABS] Ministry requirements", "Ministry", "Qatar Waste"),    ("Monitoring Plan", "[ABS] PM defines", "PM", "Qatar Waste"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

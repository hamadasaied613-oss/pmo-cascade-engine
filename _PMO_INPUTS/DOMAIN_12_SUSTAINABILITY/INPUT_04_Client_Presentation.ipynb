# %% [markdown]
# # INPUT: Client Presentation---**Output:** Client Presentation (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Client Presentation.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Client Presentation

# %%
# INPUT: Client Presentationprint("=" * 70)print("INPUT: Client Presentation")print("Output: DOMAIN 12 SUSTAINABILITY - Client Presentation")print("=" * 70)print("")inputs = [    ("Project Summary", "[REF] From all domains", "All Domains", "Client Presentation"),    ("Key Metrics", "[REF] From KPIs", "Calculation", "Client Presentation"),    ("Visual Materials", "[ABS] Architect provides", "Architect", "Client Presentation"),    ("Recommendations", "[ABS] PM recommends", "PM", "Client Presentation"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Waste Management---**Output:** Waste Management (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Waste Management.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Waste Management

# %%
# INPUT: Waste Managementprint("=" * 70)print("INPUT: Waste Management")print("Output: DOMAIN 12 SUSTAINABILITY - Waste Management")print("=" * 70)print("")inputs = [    ("Waste Types", "[ABS] Engineer identifies", "Engineer", "Waste Management"),    ("Recycling Targets", "[ABS] Client defines", "Client", "Waste Management"),    ("Disposal Methods", "[ABS] Environmental", "ENV Consultant", "Waste Management"),    ("Monitoring Plan", "[ABS] PM defines", "PM", "Waste Management"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

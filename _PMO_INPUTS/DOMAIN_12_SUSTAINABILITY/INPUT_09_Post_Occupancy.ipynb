# %% [markdown]
# # INPUT: Post Occupancy Evaluation---**Output:** Post Occupancy Evaluation (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Post Occupancy Evaluation.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Post Occupancy Evaluation

# %%
# INPUT: Post Occupancy Evaluationprint("=" * 70)print("INPUT: Post Occupancy Evaluation")print("Output: DOMAIN 12 SUSTAINABILITY - Post Occupancy Evaluation")print("=" * 70)print("")inputs = [    ("Occupancy Data", "[ABS] Building management", "Building Management", "Post Occupancy"),    ("Energy Performance", "[ABS] Meter data", "Metering", "Post Occupancy"),    ("Water Performance", "[ABS] Meter data", "Metering", "Post Occupancy"),    ("Occupant Satisfaction", "[ABS] Survey", "Survey", "Post Occupancy"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

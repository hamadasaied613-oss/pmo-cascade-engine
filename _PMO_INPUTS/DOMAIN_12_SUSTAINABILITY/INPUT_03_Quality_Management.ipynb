# %% [markdown]
# # INPUT: Quality Management---**Output:** Quality Management (Domain 12)**Standards:** ISO 9001:2015 | Six Sigma**ISO:** ISO 9001:2015## PurposeDefine quality management system for the project.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Quality Standards + Project Requirements -> **THIS INPUT** -> **ACTIVITY:** Quality Planning -> **OUTPUT:** Quality Management

# %%
# INPUT: Quality Managementprint("=" * 70)print("INPUT: Quality Management")print("Output: Domain 12 - Quality Management")print("=" * 70)print("")inputs = [    ("Quality Policy", "[ABS] Organization defines", "Organization", "Quality Management"),    ("Quality Objectives", "[ABS] Project defines", "PM", "Quality Management"),    ("Quality Standards", "[ABS] ISO 9001:2015", "STD", "Quality Management"),    ("Inspection Plan", "[ABS] Quality manager", "Quality Manager", "Quality Management"),    ("Testing Plan", "[ABS] Quality manager", "Quality Manager", "Quality Management"),    ("Non-Conformance Procedure", "[ABS] Quality manager", "Quality Manager", "NC Process"),    ("Corrective Action Procedure", "[ABS] Quality manager", "Quality Manager", "NC Process"),    ("Continuous Improvement Plan", "[ABS] Quality manager", "Quality Manager", "Quality Management"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Quality Score: CALCULATED")print("  - Improvement Areas: IDENTIFIED")print("  - Certification Status: TRACKED")

# %% [markdown]
# # INPUT: BIM Management---**Output:** BIM Management (Domain 12)**Standards:** ISO 19650 | PAS 1192**ISO:** ISO 19650:2018## PurposeDefine BIM execution and management plan.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Project Requirements + BIM Standards -> **THIS INPUT** -> **ACTIVITY:** BIM Planning -> **OUTPUT:** BIM Management

# %%
# INPUT: BIM Managementprint("=" * 70)print("INPUT: BIM Management")print("Output: Domain 12 - BIM Management")print("=" * 70)print("")inputs = [    ("BIM Execution Plan", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("LOD Requirements", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Model Coordination Rules", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Clash Detection Protocol", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Data Exchange Standards", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Common Data Environment", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Discipline Models", "[ABS] All disciplines", "All Disciplines", "BIM Management"),    ("BIM Software", "[ABS] Organization standard", "STD", "BIM Management"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - BIM Maturity Level: CALCULATED")print("  - Coordination Status: TRACKED")print("  - Data Quality: CALCULATED")

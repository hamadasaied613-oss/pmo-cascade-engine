# %% [markdown]
# # INPUT: Water Strategy---**Output:** Water Strategy (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Water Strategy.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Water Strategy

# %%
# INPUT: Water Strategyprint("=" * 70)print("INPUT: Water Strategy")print("Output: DOMAIN 12 SUSTAINABILITY - Water Strategy")print("=" * 70)print("")inputs = [    ("Water Demand", "[REF] From MEP", "D06-INPUT_03", "MEP Concept"),    ("Water Efficiency Measures", "[ABS] Engineer proposes", "Engineer", "Water Strategy"),    ("Recycling Systems", "[ABS] Engineer proposes", "Engineer", "Water Strategy"),    ("Water Target", "[ABS] Client defines", "Client", "Water Strategy"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

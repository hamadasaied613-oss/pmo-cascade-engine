# %% [markdown]
# # INPUT: Carbon Assessment---**Output:** Carbon Assessment (DOMAIN 12 SUSTAINABILITY)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Carbon Assessment.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Carbon Assessment

# %%
# INPUT: Carbon Assessmentprint("=" * 70)print("INPUT: Carbon Assessment")print("Output: DOMAIN 12 SUSTAINABILITY - Carbon Assessment")print("=" * 70)print("")inputs = [    ("Energy Consumption", "[REF] From Energy Modeling", "D12-INPUT_05", "Energy Modeling"),    ("Material Embodied Carbon", "[ABS] Material data", "Materials", "Carbon Assessment"),    ("Transportation Carbon", "[ABS] Logistics data", "Logistics", "Carbon Assessment"),    ("Carbon Reduction Target", "[ABS] Client defines", "Client", "Carbon Assessment"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

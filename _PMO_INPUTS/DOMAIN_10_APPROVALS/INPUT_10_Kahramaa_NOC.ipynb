# %% [markdown]
# # INPUT: Kahramaa NOC---**Output:** Kahramaa NOC (DOMAIN 10 APPROVALS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Kahramaa NOC.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Kahramaa NOC

# %%
# INPUT: Kahramaa NOCprint("=" * 70)print("INPUT: Kahramaa NOC")print("Output: DOMAIN 10 APPROVALS - Kahramaa NOC")print("=" * 70)print("")inputs = [    ("Electricity Application", "[ABS] Submit to Kahramaa", "Kahramaa", "Kahramaa NOC"),    ("Water Application", "[ABS] Submit to Kahramaa", "Kahramaa", "Kahramaa NOC"),    ("Technical Requirements", "[ABS] Kahramaa standards", "STD-Kahramaa", "Kahramaa NOC"),    ("NOC Status", "[ABS] Track status", "Permit Team", "Kahramaa NOC"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

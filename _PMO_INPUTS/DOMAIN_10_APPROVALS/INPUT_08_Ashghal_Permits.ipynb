# %% [markdown]
# # INPUT: Ashghal Permits---**Output:** Ashghal Permits (DOMAIN 10 APPROVALS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Ashghal Permits.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Ashghal Permits

# %%
# INPUT: Ashghal Permitsprint("=" * 70)print("INPUT: Ashghal Permits")print("Output: DOMAIN 10 APPROVALS - Ashghal Permits")print("=" * 70)print("")inputs = [    ("Building Permit Application", "[ABS] Submit to Ashghal", "Ashghal", "Ashghal Permits"),    ("Design Approval", "[ABS] Ashghal reviews", "Ashghal", "Ashghal Permits"),    ("Construction Permit", "[ABS] Ashghal issues", "Ashghal", "Ashghal Permits"),    ("Occupation Certificate", "[ABS] Ashghal issues", "Ashghal", "Ashghal Permits"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Authority Matrix---**Output:** Authority Matrix (Domain 10)**Standards:** Authority Requirements**ISO:** ISO 21500:2012## PurposeMap all authority requirements and interfaces.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Project Scope + Authority Requirements -> **THIS INPUT** -> **ACTIVITY:** Authority Mapping -> **OUTPUT:** Authority Matrix

# %%
# INPUT: Authority Matrixprint("=" * 70)print("INPUT: Authority Matrix")print("Output: Domain 10 - Authority Matrix")print("=" * 70)print("")inputs = [    ("Municipality Requirements", "[ABS] Municipality schedule", "ACT-Municipality", "Permit Tracker"),    ("Civil Defence Requirements", "[ABS] Civil Defence code", "STD-FireCode", "Fire Approval"),    ("DEWA Requirements", "[ABS] DEWA standards", "STD-DEWA", "DEWA NOC"),    ("RTA Requirements", "[ABS] RTA standards", "STD-RTA", "Traffic Approval"),    ("Environmental Authority", "[ABS] EAD requirements", "STD-EAD", "Environmental"),    ("Health Authority", "[ABS] HAAD requirements", "STD-HAAD", "Health Approval"),    ("Telecom Authority", "[ABS] TDRA requirements", "STD-TDRA", "Telecom Approval"),    ("Water Authority", "[ABS] SWA requirements", "STD-SWA", "Water Approval"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Authority Matrix: AUTO-GENERATED")print("  - Requirement Checklist: CALCULATED")print("  - Compliance Status: CALCULATED")

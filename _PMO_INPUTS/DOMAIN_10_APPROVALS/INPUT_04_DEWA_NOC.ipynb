# %% [markdown]
# # INPUT: DEWA NOC---**Output:** DEWA NOC (DOMAIN 10 APPROVALS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for DEWA NOC.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** DEWA NOC

# %%
# INPUT: DEWA NOCprint("=" * 70)print("INPUT: DEWA NOC")print("Output: DOMAIN 10 APPROVALS - DEWA NOC")print("=" * 70)print("")inputs = [    ("DEWA Application", "[ABS] Submit to DEWA", "DEWA", "DEWA NOC"),    ("Technical Requirements", "[ABS] DEWA standards", "STD-DEWA", "DEWA NOC"),    ("Inspection Schedule", "[ABS] DEWA schedules", "DEWA", "DEWA NOC"),    ("NOC Status", "[ABS] Track status", "Permit Team", "DEWA NOC"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

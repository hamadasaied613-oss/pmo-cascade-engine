# %% [markdown]
# # INPUT: Civil Defence NOC---**Output:** Civil Defence NOC (DOMAIN 10 APPROVALS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Civil Defence NOC.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Civil Defence NOC

# %%
# INPUT: Civil Defence NOCprint("=" * 70)print("INPUT: Civil Defence NOC")print("Output: DOMAIN 10 APPROVALS - Civil Defence NOC")print("=" * 70)print("")inputs = [    ("Fire Concept", "[ABS] Fire consultant", "Fire Consultant", "Civil Defence NOC"),    ("Fire Drawings", "[ABS] Fire consultant", "Fire Consultant", "Civil Defence NOC"),    ("Site Inspection", "[ABS] Civil Defence inspects", "Civil Defence", "Civil Defence NOC"),    ("NOC Issued", "[ABS] Civil Defence issues", "Civil Defence", "Civil Defence NOC"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

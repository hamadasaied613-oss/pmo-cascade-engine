# %% [markdown]
# # INPUT: Permit Tracker---**Output:** Permit Tracker (Domain 10)**Standards:** Authority Approval Process**ISO:** ISO 21500:2012## PurposeTrack all permit applications and approvals.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Design Drawings + Applications -> **THIS INPUT** -> **ACTIVITY:** Permit Tracking -> **OUTPUT:** Permit Tracker

# %%
# INPUT: Permit Trackerprint("=" * 70)print("INPUT: Permit Tracker")print("Output: Domain 10 - Permit Tracker")print("=" * 70)print("")inputs = [    ("Building Permit Application", "[ABS] Submit to Municipality", "Municipality", "Permit Tracker"),    ("Fire Safety Application", "[ABS] Submit to Civil Defence", "Civil Defence", "Fire Approval"),    ("DEWA Application", "[ABS] Submit to DEWA", "DEWA", "DEWA NOC"),    ("RTA Application", "[ABS] Submit to RTA", "RTA", "Traffic Approval"),    ("Environmental Application", "[ABS] Submit to EAD", "EAD", "Environmental"),    ("Health Authority Application", "[ABS] Submit to HAAD", "HAAD", "Health Approval"),    ("Telecom Application", "[ABS] Submit to TDRA", "TDRA", "Telecom Approval"),    ("Drawing Submission Status", "[ABS] Track submissions", "Permit Team", "Permit Tracker"),    ("Authority Comments", "[ABS] Track responses", "Permit Team", "Permit Tracker"),    ("Resubmission Status", "[ABS] Track resubmissions", "Permit Team", "Permit Tracker"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Permit Status: TRACKED")print("  - Approval Timeline: CALCULATED")print("  - Critical Path Permits: IDENTIFIED")

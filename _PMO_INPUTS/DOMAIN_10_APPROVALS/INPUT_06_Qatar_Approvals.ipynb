# %% [markdown]
# # INPUT: Qatar Approvals---**Output:** Qatar Approvals (DOMAIN 10 APPROVALS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Qatar Approvals.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Qatar Approvals

# %%
# INPUT: Qatar Approvalsprint("=" * 70)print("INPUT: Qatar Approvals")print("Output: DOMAIN 10 APPROVALS - Qatar Approvals")print("=" * 70)print("")inputs = [    ("Ashghal Application", "[ABS] Submit to Ashghal", "Ashghal", "Qatar Approvals"),    ("Kahramaa Application", "[ABS] Submit to Kahramaa", "Kahramaa", "Qatar Approvals"),    ("Civil Defence Application", "[ABS] Submit to Civil Defence", "Civil Defence", "Qatar Approvals"),    ("Approval Status", "[ABS] Track status", "Permit Team", "Qatar Approvals"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

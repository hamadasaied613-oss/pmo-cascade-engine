# %% [markdown]
# # INPUT: Fire Approval---**Output:** Fire Approval (Domain 10)**Standards:** Civil Defence Code | NFPA**ISO:** ISO 21500:2012## PurposeTrack fire safety approval process.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Fire Safety Design + Application -> **THIS INPUT** -> **ACTIVITY:** Fire Approval -> **OUTPUT:** Fire Approval

# %%
# INPUT: Fire Approvalprint("=" * 70)print("INPUT: Fire Approval")print("Output: Domain 10 - Fire Approval")print("=" * 70)print("")inputs = [    ("Fire Safety Concept", "[REF] From Fire Safety Design", "D06-INPUT_05", "Fire Safety"),    ("Fire Strategy Report", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Fire Drawings", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Fire Equipment Schedule", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Evacuation Plan", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Application Status", "[ABS] Track submission", "Permit Team", "Permit Tracker"),    ("Authority Comments", "[ABS] Track responses", "Permit Team", "Permit Tracker"),    ("Site Inspection Date", "[ABS] Schedule inspection", "Permit Team", "Inspection Checklist"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Fire NOC Status: TRACKED")print("  - Approval Timeline: CALCULATED")print("  - Compliance Status: CALCULATED")

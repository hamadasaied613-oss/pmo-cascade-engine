# %% [markdown]
# # INPUT: Unified Bill of Quantities---**Output:** Unified BOQ (Cross-Domain)**Standards:** CESMM4 | NRM | POMI**ISO:** ISO 12006:2015## PurposeConsolidate all BOQ data into unified format.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Domain 08 BOQ + Domain 06 Specs -> **THIS INPUT** -> **ACTIVITY:** BOQ Consolidation -> **OUTPUT:** Unified BOQ

# %%
# INPUT: Unified BOQprint("=" * 70)print("INPUT: Unified Bill of Quantities")print("Output: Cross-Domain - Unified BOQ")print("=" * 70)print("")inputs = [    ("Architectural BOQ", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("Structural BOQ", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("MEP BOQ", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("External Works BOQ", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("Preliminaries", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("Contingency", "[REF] From Risk Register", "D01-INPUT_04", "Risk Register"),    ("Rate Analysis", "[ABS] Market rates", "Market Rates", "Cost Estimate"),    ("Measurement Method", "[ABS] CESMM4/POMI", "STD", "BOQ"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Total BOQ Value: CALCULATED")print("  - Rate Analysis: CALCULATED")print("  - Cost Breakdown: CALCULATED")

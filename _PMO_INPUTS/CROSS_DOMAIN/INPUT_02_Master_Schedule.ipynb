# %% [markdown]
# # INPUT: Master Schedule---**Output:** Master Schedule (Cross-Domain)**Standards:** PMI-PMBOK | RIBA Plan of Work**ISO:** ISO 21500:2012## PurposeConsolidate all schedule data into master timeline.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Domain 09 Schedule + Domain 10 Approvals -> **THIS INPUT** -> **ACTIVITY:** Schedule Consolidation -> **OUTPUT:** Master Schedule

# %%
# INPUT: Master Scheduleprint("=" * 70)print("INPUT: Master Schedule")print("Output: Cross-Domain - Master Schedule")print("=" * 70)print("")inputs = [    ("Design Phase Schedule", "[REF] From Domain 06", "D06-INPUT_01", "Design Parameters"),    ("Procurement Schedule", "[REF] From Domain 08", "D08-INPUT_01", "BOQ"),    ("Construction Schedule", "[REF] From Domain 09", "D09-INPUT_01", "Master Program"),    ("Approval Schedule", "[REF] From Domain 10", "D10-INPUT_01", "Permit Tracker"),    ("Commissioning Schedule", "[ABS] MEP engineer", "MEP Eng", "MEP Concept"),    ("Handover Schedule", "[ABS] PM defines", "PM", "Handover Plan"),    ("Milestone Dates", "[REF] From Client Brief", "D01-INPUT_05", "Client Brief"),    ("Resource Availability", "[REF] From Resource Loading", "D09-INPUT_06", "Resource Loading"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Total Duration: CALCULATED")print("  - Critical Path: CALCULATED")print("  - Milestone Dates: CALCULATED")

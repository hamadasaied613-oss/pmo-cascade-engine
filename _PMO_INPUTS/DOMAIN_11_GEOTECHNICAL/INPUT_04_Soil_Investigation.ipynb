# %% [markdown]
# # INPUT: Soil Investigation---**Output:** Soil Investigation (DOMAIN 11 GEOTECHNICAL)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Soil Investigation.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Soil Investigation

# %%
# INPUT: Soil Investigationprint("=" * 70)print("INPUT: Soil Investigation")print("Output: DOMAIN 11 GEOTECHNICAL - Soil Investigation")print("=" * 70)print("")inputs = [    ("Borehole Data", "[ABS] Site investigation", "Geotech Consultant", "Soil Investigation"),    ("Lab Test Results", "[ABS] Lab testing", "Geotech Consultant", "Soil Investigation"),    ("Soil Classification", "[ABS] Lab testing", "Geotech Consultant", "Soil Investigation"),    ("Recommendations", "[ABS] Geotech recommends", "Geotech Consultant", "Soil Investigation"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Geotechnical Report---**Output:** Geotechnical Report (Domain 11)**Standards:** ASTM | BS 5930 | Local Codes**ISO:** ISO 21500:2012## PurposeCollect soil investigation data for foundation design.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Borehole Data + Laboratory Tests -> **THIS INPUT** -> **ACTIVITY:** Geotechnical Analysis -> **OUTPUT:** Geotechnical Report

# %%
# INPUT: Geotechnical Reportprint("=" * 70)print("INPUT: Geotechnical Report")print("Output: Domain 11 - Geotechnical Report")print("=" * 70)print("")inputs = [    ("Borehole Locations", "[ABS] Site investigation", "Geotech Consultant", "Geotechnical Report"),    ("Borehole Depths (m)", "[ABS] Site investigation", "Geotech Consultant", "Geotechnical Report"),    ("Soil Profile", "[ABS] Borehole logging", "Geotech Consultant", "Geotechnical Report"),    ("SPT N-Values", "[ABS] Standard Penetration", "Geotech Consultant", "Geotechnical Report"),    ("Cone Penetration (CPT)", "[ABS] CPT testing", "Geotech Consultant", "Geotechnical Report"),    ("Laboratory Test Results", "[ABS] Lab testing", "Geotech Consultant", "Geotechnical Report"),    ("Groundwater Level (m)", "[ABS] Piezometer reading", "Geotech Consultant", "Dewatering Plan"),    ("Soil Classification", "[ABS] Lab testing", "Geotech Consultant", "Foundation Design"),    ("Bearing Capacity", "[ABS] Calculation", "Geotech Consultant", "Foundation Design"),    ("Settlement Estimation", "[ABS] Calculation", "Geotech Consultant", "Foundation Design"),    ("Liquefaction Assessment", "[ABS] Seismic analysis", "Geotech Consultant", "Foundation Design"),    ("Rock Profile", "[ABS] Borehole logging", "Geotech Consultant", "Geotechnical Report"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Soil Classification: CALCULATED")print("  - Bearing Capacity: CALCULATED")print("  - Settlement: CALCULATED")

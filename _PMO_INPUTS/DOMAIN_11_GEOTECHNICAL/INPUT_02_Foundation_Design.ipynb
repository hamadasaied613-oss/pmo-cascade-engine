# %% [markdown]
# # INPUT: Foundation Design---**Output:** Foundation Design (Domain 11)**Standards:** ACI 318 | Eurocode 7**ISO:** ISO 21500:2012## PurposeDesign foundation system based on geotechnical data.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Geotechnical Report + Structural Loads -> **THIS INPUT** -> **ACTIVITY:** Foundation Design -> **OUTPUT:** Foundation Design

# %%
# INPUT: Foundation Designprint("=" * 70)print("INPUT: Foundation Design")print("Output: Domain 11 - Foundation Design")print("=" * 70)print("")inputs = [    ("Geotechnical Report", "[REF] From Geotech", "D11-INPUT_01", "Geotechnical Report"),    ("Column Loads (kN)", "[REF] From Structural", "D06-INPUT_02", "Structural Concept"),    ("Bearing Capacity", "[REF] From Geotech", "D11-INPUT_01", "Geotechnical Report"),    ("Settlement Limits", "[ABS] Structural engineer", "Structural Eng", "Foundation Design"),    ("Groundwater Level", "[REF] From Geotech", "D11-INPUT_01", "Dewatering Plan"),    ("Foundation Type Selection", "[ABS] Geotech recommendation", "Geotech Consultant", "Foundation Design"),    ("Pile Type", "[ABS] Geotech recommendation", "Geotech Consultant", "Foundation Design"),    ("Pile Length (m)", "[ABS] Geotech recommendation", "Geotech Consultant", "Foundation Design"),    ("Pile Capacity (kN)", "[ABS] Geotech recommendation", "Geotech Consultant", "Foundation Design"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Foundation Type: CALCULATED")print("  - Pile Layout: CALCULATED")print("  - Foundation Cost: CALCULATED")

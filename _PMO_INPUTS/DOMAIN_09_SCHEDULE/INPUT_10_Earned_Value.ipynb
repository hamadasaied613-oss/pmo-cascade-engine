# %% [markdown]
# # INPUT: Earned Value Analysis---**Output:** Earned Value Analysis (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Earned Value Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Earned Value Analysis

# %%
# INPUT: Earned Value Analysisprint("=" * 70)print("INPUT: Earned Value Analysis")print("Output: DOMAIN 09 SCHEDULE - Earned Value Analysis")print("=" * 70)print("")inputs = [    ("Planned Value", "[REF] From Schedule", "D09-INPUT_01", "Master Program"),    ("Earned Value", "[ABS] Site progress", "Site Team", "Earned Value"),    ("Actual Cost", "[ABS] Financial records", "Finance", "Cash Flow"),    ("Performance Metrics", "[ABS] PM calculates", "PM", "Earned Value"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

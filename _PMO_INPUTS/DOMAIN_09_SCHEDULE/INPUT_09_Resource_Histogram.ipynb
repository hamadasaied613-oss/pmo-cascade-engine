# %% [markdown]
# # INPUT: Resource Histogram---**Output:** Resource Histogram (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Resource Histogram.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Resource Histogram

# %%
# INPUT: Resource Histogramprint("=" * 70)print("INPUT: Resource Histogram")print("Output: DOMAIN 09 SCHEDULE - Resource Histogram")print("=" * 70)print("")inputs = [    ("Resource Data", "[REF] From Resource Loading", "D09-INPUT_06", "Resource Loading"),    ("Time Period", "[ABS] PM defines", "PM", "Resource Histogram"),    ("Peak Requirements", "[ABS] PM calculates", "PM", "Resource Histogram"),    ("Smoothing Options", "[ABS] PM evaluates", "PM", "Resource Histogram"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

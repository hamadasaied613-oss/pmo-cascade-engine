# %% [markdown]
# # INPUT: Master Program---**Output:** Master Program (Domain 09)**Standards:** PMI-PMBOK Schedule | RIBA Plan of Work**ISO:** ISO 21500:2012## PurposeDevelop master project schedule.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Project Scope + Resources -> **THIS INPUT** -> **ACTIVITY:** Schedule Development -> **OUTPUT:** Master Program

# %%
# INPUT: Master Programprint("=" * 70)print("INPUT: Master Program")print("Output: Domain 09 - Master Program")print("=" * 70)print("")inputs = [    ("Project Scope", "[REF] From Project Charter", "D01-INPUT_02", "Project Charter"),    ("Activity List", "[ABS] PM develops", "PM", "Master Program"),    ("Activity Durations", "[ABS] PM estimates", "PM", "Master Program"),    ("Resource Requirements", "[ABS] PM assigns", "PM", "Resource Loading"),    ("Logical Relationships", "[ABS] PM defines", "PM", "Critical Path"),    ("Constraints", "[ABS] PM identifies", "PM", "Master Program"),    ("Assumptions", "[ABS] PM identifies", "PM", "Master Program"),    ("Milestones", "[ABS] Client defines", "Client", "Master Program"),    ("Calendar", "[ABS] Working days", "STD", "Master Program"),    ("Lag/Lead Times", "[ABS] PM defines", "PM", "Master Program"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Project Duration: CALCULATED")print("  - Critical Path: CALCULATED")print("  - Float Analysis: CALCULATED")

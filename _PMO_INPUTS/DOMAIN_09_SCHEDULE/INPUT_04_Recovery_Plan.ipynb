# %% [markdown]
# # INPUT: Recovery Plan---**Output:** Recovery Plan (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Recovery Plan.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Recovery Plan

# %%
# INPUT: Recovery Planprint("=" * 70)print("INPUT: Recovery Plan")print("Output: DOMAIN 09 SCHEDULE - Recovery Plan")print("=" * 70)print("")inputs = [    ("Delay Cause", "[ABS] PM identifies", "PM", "Recovery Plan"),    ("Recovery Options", "[ABS] PM develops", "PM", "Recovery Plan"),    ("Resource Requirements", "[ABS] PM calculates", "PM", "Recovery Plan"),    ("Cost Impact", "[ABS] QS calculates", "QS", "Recovery Plan"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

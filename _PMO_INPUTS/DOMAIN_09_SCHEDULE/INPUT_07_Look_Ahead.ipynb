# %% [markdown]
# # INPUT: Look Ahead Schedule---**Output:** Look Ahead Schedule (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Look Ahead Schedule.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Look Ahead Schedule

# %%
# INPUT: Look Ahead Scheduleprint("=" * 70)print("INPUT: Look Ahead Schedule")print("Output: DOMAIN 09 SCHEDULE - Look Ahead Schedule")print("=" * 70)print("")inputs = [    ("4-Week Activities", "[ABS] PM develops", "PM", "Look Ahead"),    ("Resource Requirements", "[ABS] PM plans", "PM", "Look Ahead"),    ("Material Requirements", "[ABS] PM plans", "PM", "Look Ahead"),    ("Constraints", "[ABS] PM identifies", "PM", "Look Ahead"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Monte Carlo Simulation---**Output:** Monte Carlo Simulation (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Monte Carlo Simulation.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Monte Carlo Simulation

# %%
# INPUT: Monte Carlo Simulationprint("=" * 70)print("INPUT: Monte Carlo Simulation")print("Output: DOMAIN 09 SCHEDULE - Monte Carlo Simulation")print("=" * 70)print("")inputs = [    ("Activity Durations", "[ABS] PM estimates", "PM", "Monte Carlo"),    ("Risk Factors", "[REF] From Risk Register", "D01-INPUT_04", "Risk Register"),    ("Correlation Factors", "[ABS] PM defines", "PM", "Monte Carlo"),    ("Simulation Parameters", "[ABS] PM defines", "PM", "Monte Carlo"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

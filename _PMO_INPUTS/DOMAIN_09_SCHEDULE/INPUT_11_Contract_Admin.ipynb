# %% [markdown]
# # INPUT: Contract Administration---**Output:** Contract Administration (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Contract Administration.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Contract Administration

# %%
# INPUT: Contract Administrationprint("=" * 70)print("INPUT: Contract Administration")print("Output: DOMAIN 09 SCHEDULE - Contract Administration")print("=" * 70)print("")inputs = [    ("Contract Terms", "[ABS] Legal review", "Legal", "Contract Admin"),    ("Payment Certificates", "[ABS] QS prepares", "QS", "Contract Admin"),    ("Variation Orders", "[ABS] PM processes", "PM", "Contract Admin"),    ("Claims Management", "[ABS] PM manages", "PM", "Contract Admin"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Delay Analysis---**Output:** Delay Analysis (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Delay Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Delay Analysis

# %%
# INPUT: Delay Analysisprint("=" * 70)print("INPUT: Delay Analysis")print("Output: DOMAIN 09 SCHEDULE - Delay Analysis")print("=" * 70)print("")inputs = [    ("Delay Events", "[ABS] PM records", "PM", "Delay Analysis"),    ("Critical Path Impact", "[ABS] PM analyzes", "PM", "Delay Analysis"),    ("Entitlement Assessment", "[ABS] PM evaluates", "PM", "Delay Analysis"),    ("Claim Documentation", "[ABS] PM prepares", "PM", "Delay Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

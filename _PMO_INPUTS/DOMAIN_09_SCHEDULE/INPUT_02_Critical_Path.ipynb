# %% [markdown]
# # INPUT: Critical Path Analysis---**Output:** Critical Path Analysis (Domain 09)**Standards:** CPM/PERT | PMI-PMBOK**ISO:** ISO 21500:2012## PurposeIdentify critical path and float analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Master Program + Logic -> **THIS INPUT** -> **ACTIVITY:** CPM Analysis -> **OUTPUT:** Critical Path Analysis

# %%
# INPUT: Critical Path Analysisprint("=" * 70)print("INPUT: Critical Path Analysis")print("Output: Domain 09 - Critical Path Analysis")print("=" * 70)print("")inputs = [    ("Activity List", "[REF] From Master Program", "D09-INPUT_01", "Master Program"),    ("Duration Estimates", "[REF] From Master Program", "D09-INPUT_01", "Master Program"),    ("Predecessor Relationships", "[ABS] PM defines", "PM", "Critical Path"),    ("Resource Constraints", "[ABS] PM identifies", "PM", "Resource Loading"),    ("External Dependencies", "[ABS] PM identifies", "PM", "Critical Path"),    ("Milestone Dates", "[REF] From Client Brief", "D01-INPUT_05", "Client Brief"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Critical Path: CALCULATED")print("  - Total Float: CALCULATED")print("  - Free Float: CALCULATED")

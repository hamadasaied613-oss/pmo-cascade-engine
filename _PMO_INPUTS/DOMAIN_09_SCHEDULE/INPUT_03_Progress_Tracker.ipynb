# %% [markdown]
# # INPUT: Progress Tracker (EVM)---**Output:** Progress Tracker (Domain 09)**Standards:** PMI-PMBOK Earned Value**ISO:** ISO 21500:2012## PurposeTrack project performance using Earned Value Management.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Schedule + Actual Progress -> **THIS INPUT** -> **ACTIVITY:** EVM Analysis -> **OUTPUT:** Progress Tracker

# %%
# INPUT: Progress Tracker (EVM)print("=" * 70)print("INPUT: Progress Tracker (EVM)")print("Output: Domain 09 - Progress Tracker")print("=" * 70)print("")inputs = [    ("Planned Value (PV)", "[REF] From Master Program", "D09-INPUT_01", "Master Program"),    ("Earned Value (EV)", "[ABS] Site progress", "Site Team", "Progress Tracker"),    ("Actual Cost (AC)", "[ABS] Financial records", "Finance", "Cash Flow"),    ("Budget at Completion (BAC)", "[REF] From Cost Estimate", "D08-INPUT_02", "Cost Estimate"),    ("Reporting Period", "[ABS] PM defines", "PM", "Progress Tracker"),    ("Physical Progress (%)", "[ABS] Site measurement", "Site Team", "Progress Tracker"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Schedule Variance (SV): CALCULATED")print("  - Cost Variance (CV): CALCULATED")print("  - SPI/CPI: CALCULATED")print("  - EAC/ETC: CALCULATED")

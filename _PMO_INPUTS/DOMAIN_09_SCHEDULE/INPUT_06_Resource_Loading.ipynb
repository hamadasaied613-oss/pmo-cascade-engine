# %% [markdown]
# # INPUT: Resource Loading---**Output:** Resource Loading (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Resource Loading.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Resource Loading

# %%
# INPUT: Resource Loadingprint("=" * 70)print("INPUT: Resource Loading")print("Output: DOMAIN 09 SCHEDULE - Resource Loading")print("=" * 70)print("")inputs = [    ("Resource Types", "[ABS] PM identifies", "PM", "Resource Loading"),    ("Resource Quantities", "[ABS] PM calculates", "PM", "Resource Loading"),    ("Resource Availability", "[ABS] PM confirms", "PM", "Resource Loading"),    ("Resource Cost", "[ABS] PM estimates", "PM", "Resource Loading"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

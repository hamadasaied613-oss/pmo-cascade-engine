# %% [markdown]
# # INPUT: Program Management---**Output:** Program Management (DOMAIN 09 SCHEDULE)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Program Management.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Program Management

# %%
# INPUT: Program Managementprint("=" * 70)print("INPUT: Program Management")print("Output: DOMAIN 09 SCHEDULE - Program Management")print("=" * 70)print("")inputs = [    ("Project Portfolio", "[ABS] PM manages", "PM", "Program Management"),    ("Resource Allocation", "[ABS] PM optimizes", "PM", "Program Management"),    ("Risk Management", "[ABS] PM manages", "PM", "Program Management"),    ("Stakeholder Management", "[ABS] PM manages", "PM", "Program Management"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

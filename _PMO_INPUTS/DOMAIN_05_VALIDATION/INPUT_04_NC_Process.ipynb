# %% [markdown]
# # INPUT: Non-Conformance Process---**Output:** Non-Conformance Process (DOMAIN 05 VALIDATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Non-Conformance Process.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Non-Conformance Process

# %%
# INPUT: Non-Conformance Processprint("=" * 70)print("INPUT: Non-Conformance Process")print("Output: DOMAIN 05 VALIDATION - Non-Conformance Process")print("=" * 70)print("")inputs = [    ("NC Description", "[ABS] Team reports", "Team", "NC Process"),    ("Root Cause", "[ABS] Team analyzes", "Team", "NC Process"),    ("Corrective Action", "[ABS] Team proposes", "Team", "NC Process"),    ("Verification", "[ABS] QA verifies", "QA", "NC Process"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Compliance Audit---**Output:** Compliance Audit (Domain 05)**Standards:** ISO 9001:2015 | Quality Audit**ISO:** ISO 9001:2015## PurposeVerify compliance with all applicable codes and standards.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** All Domain Outputs + Standards -> **THIS INPUT** -> **ACTIVITY:** Compliance Check -> **OUTPUT:** Compliance Audit

# %%
# INPUT: Compliance Auditprint("=" * 70)print("INPUT: Compliance Audit")print("Output: Domain 05 - Compliance Audit")print("=" * 70)print("")inputs = [    ("Building Code Reference", "[ABS] Applicable code", "STD-Code", "Compliance Audit"),    ("Fire Code Reference", "[ABS] Applicable code", "STD-FireCode", "Fire Safety"),    ("Accessibility Code", "[ABS] Applicable code", "STD-Accessibility", "Accessibility"),    ("Environmental Code", "[ABS] Applicable code", "STD-Environmental", "Environmental"),    ("Zoning Compliance Status", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("Structural Compliance", "[REF] From Structural", "D06-INPUT_02", "Structural Concept"),    ("MEP Compliance", "[REF] From MEP", "D06-INPUT_03", "MEP Concept"),    ("Fire Safety Compliance", "[REF] From Fire Safety", "D06-INPUT_05", "Fire Safety"),    ("Document Control Status", "[REF] From Document Control", "D05-INPUT_05", "Document Control"),    ("Non-Conformance Log", "[REF] From NC Process", "D05-INPUT_04", "NC Process"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Compliance Score: CALCULATED")print("  - Non-Compliance Items: LIST")print("  - Corrective Actions: CALCULATED")

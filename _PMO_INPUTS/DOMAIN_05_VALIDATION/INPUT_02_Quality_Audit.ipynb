# %% [markdown]
# # INPUT: Quality Audit---**Output:** Quality Audit (Domain 05)**Standards:** ISO 9001:2015 | Six Sigma**ISO:** ISO 9001:2015## PurposeAssess quality management system effectiveness.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Quality Records + Standards -> **THIS INPUT** -> **ACTIVITY:** Quality Assessment -> **OUTPUT:** Quality Audit

# %%
# INPUT: Quality Auditprint("=" * 70)print("INPUT: Quality Audit")print("Output: Domain 05 - Quality Audit")print("=" * 70)print("")inputs = [    ("Quality Policy", "[ABS] Organization defines", "Organization", "Quality Management"),    ("Quality Objectives", "[ABS] Organization defines", "Organization", "Quality Management"),    ("Quality Records", "[REF] From Project Records", "Project Records", "Quality Audit"),    ("Inspection Records", "[REF] From Inspections", "ACT-Inspection", "Quality Audit"),    ("Test Records", "[REF] From Testing", "ACT-Testing", "Quality Audit"),    ("Non-Conformance Reports", "[REF] From NC Process", "D05-INPUT_04", "NC Process"),    ("Corrective Action Log", "[REF] From Corrective Actions", "ACT-Corrective", "Quality Audit"),    ("Supplier Quality Records", "[REF] From Supplier Quality", "D05-INPUT_06", "Supplier Quality"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Quality Score: CALCULATED")print("  - Improvement Areas: CALCULATED")print("  - Certification Status: CALCULATED")

# %% [markdown]
# # INPUT: Document Control---**Output:** Document Control (DOMAIN 05 VALIDATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Document Control.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Document Control

# %%
# INPUT: Document Controlprint("=" * 70)print("INPUT: Document Control")print("Output: DOMAIN 05 VALIDATION - Document Control")print("=" * 70)print("")inputs = [    ("Document List", "[ABS] PM maintains", "PM", "Document Control"),    ("Revision Status", "[ABS] PM tracks", "PM", "Document Control"),    ("Approval Status", "[ABS] PM tracks", "PM", "Document Control"),    ("Distribution List", "[ABS] PM maintains", "PM", "Document Control"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

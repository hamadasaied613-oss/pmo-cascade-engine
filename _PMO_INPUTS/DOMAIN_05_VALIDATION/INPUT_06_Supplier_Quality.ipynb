# %% [markdown]
# # INPUT: Supplier Quality---**Output:** Supplier Quality (DOMAIN 05 VALIDATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Supplier Quality.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Supplier Quality

# %%
# INPUT: Supplier Qualityprint("=" * 70)print("INPUT: Supplier Quality")print("Output: DOMAIN 05 VALIDATION - Supplier Quality")print("=" * 70)print("")inputs = [    ("Supplier List", "[ABS] Procurement", "Procurement", "Supplier Quality"),    ("Quality Records", "[ABS] Supplier provides", "Supplier", "Supplier Quality"),    ("Inspection Results", "[ABS] QA inspects", "QA", "Supplier Quality"),    ("Non-Conformance", "[ABS] QA reports", "QA", "Supplier Quality"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Standards Cross-Reference---**Output:** Standards Cross-Reference (Domain 05)**Standards:** ISO Standards Matrix**ISO:** ISO 9001:2015## PurposeMap all applicable standards to project deliverables.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Project Scope + Standards Database -> **THIS INPUT** -> **ACTIVITY:** Standards Mapping -> **OUTPUT:** Standards Cross-Reference

# %%
# INPUT: Standards Cross-Referenceprint("=" * 70)print("INPUT: Standards Cross-Reference")print("Output: Domain 05 - Standards Cross-Reference")print("=" * 70)print("")inputs = [    ("ISO 9001:2015 Compliance", "[ABS] QMS assessment", "QM", "Quality Management"),    ("ISO 14001:2015 Compliance", "[ABS] EMS assessment", "EM", "Environmental"),    ("ISO 45001:2018 Compliance", "[ABS] OHS assessment", "OHS", "Safety Management"),    ("ISO 19650 Compliance", "[ABS] BIM assessment", "BIM", "BIM Management"),    ("ISO 31000 Compliance", "[ABS] Risk assessment", "Risk", "Risk Register"),    ("Building Code Compliance", "[ABS] Code review", "STD-Code", "Compliance Audit"),    ("Fire Code Compliance", "[ABS] Fire review", "STD-FireCode", "Fire Safety"),    ("Accessibility Code Compliance", "[ABS] Access review", "STD-Accessibility", "Accessibility"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Standards Matrix: AUTO-GENERATED")print("  - Gap Analysis: CALCULATED")print("  - Compliance Status: CALCULATED")

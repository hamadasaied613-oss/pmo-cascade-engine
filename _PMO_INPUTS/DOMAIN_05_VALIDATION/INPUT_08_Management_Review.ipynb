# %% [markdown]
# # INPUT: Management Review---**Output:** Management Review (DOMAIN 05 VALIDATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Management Review.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Management Review

# %%
# INPUT: Management Reviewprint("=" * 70)print("INPUT: Management Review")print("Output: DOMAIN 05 VALIDATION - Management Review")print("=" * 70)print("")inputs = [    ("Review Agenda", "[ABS] PM prepares", "PM", "Management Review"),    ("Performance Data", "[ABS] PM compiles", "PM", "Management Review"),    ("Decisions", "[ABS] Management decides", "Management", "Management Review"),    ("Action Items", "[ABS] PM records", "PM", "Management Review"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

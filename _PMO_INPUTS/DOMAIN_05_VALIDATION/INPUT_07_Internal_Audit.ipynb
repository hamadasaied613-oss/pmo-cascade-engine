# %% [markdown]
# # INPUT: Internal Audit---**Output:** Internal Audit (DOMAIN 05 VALIDATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Internal Audit.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Internal Audit

# %%
# INPUT: Internal Auditprint("=" * 70)print("INPUT: Internal Audit")print("Output: DOMAIN 05 VALIDATION - Internal Audit")print("=" * 70)print("")inputs = [    ("Audit Scope", "[ABS] QA defines", "QA", "Internal Audit"),    ("Audit Findings", "[ABS] Auditor records", "Auditor", "Internal Audit"),    ("Corrective Actions", "[ABS] Team implements", "Team", "Internal Audit"),    ("Follow-up Status", "[ABS] QA tracks", "QA", "Internal Audit"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

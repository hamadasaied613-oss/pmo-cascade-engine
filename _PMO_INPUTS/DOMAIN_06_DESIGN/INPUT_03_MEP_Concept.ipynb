# %% [markdown]
# # INPUT: MEP Concept---**Output:** MEP Concept (Domain 06)**Standards:** ASHRAE | DEWA Standards | Kahramaa**ISO:** ISO 21500:2012## PurposeDefine mechanical, electrical, and plumbing systems.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Building Program + Utility Data -> **THIS INPUT** -> **ACTIVITY:** MEP Design -> **OUTPUT:** MEP Concept

# %%
# INPUT: MEP Conceptprint("=" * 70)print("INPUT: MEP Concept")print("Output: Domain 06 - MEP Concept")print("=" * 70)print("")inputs = [    ("Cooling Load (TR)", "[ABS] Heat gain calculation", "MEP Eng", "MEP Concept"),    ("Heating Load (kW)", "[ABS] Heat loss calculation", "MEP Eng", "MEP Concept"),    ("Electrical Load (kVA)", "[ABS] Power calculation", "MEP Eng", "MEP Concept"),    ("Water Demand (m3/day)", "[ABS] Plumbing calculation", "MEP Eng", "MEP Concept"),    ("Sewage Flow (m3/day)", "[ABS] Plumbing calculation", "MEP Eng", "MEP Concept"),    ("Fire Pump Capacity", "[ABS] Fire code requirement", "STD-FireCode", "Fire Safety"),    ("Generator Capacity", "[ABS] Critical load calculation", "MEP Eng", "MEP Concept"),    ("UPS Capacity", "[ABS] IT load calculation", "MEP Eng", "MEP Concept"),    ("Lift Quantity", "[ABS] Traffic calculation", "Vertical Transport", "MEP Concept"),    ("BMS Requirements", "[ABS] Automation scope", "MEP Eng", "MEP Concept"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - MEP Systems: CALCULATED")print("  - Equipment Schedule: CALCULATED")print("  - Utility Requirements: CALCULATED")

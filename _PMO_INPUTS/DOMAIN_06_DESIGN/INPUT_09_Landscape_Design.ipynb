# %% [markdown]
# # INPUT: Landscape Design---**Output:** Landscape Design (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Landscape Design.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Landscape Design

# %%
# INPUT: Landscape Designprint("=" * 70)print("INPUT: Landscape Design")print("Output: DOMAIN 06 DESIGN - Landscape Design")print("=" * 70)print("")inputs = [    ("Landscape Concept", "[ABS] Landscape architect", "Landscape Arch", "Landscape"),    ("Plant Selection", "[ABS] Landscape architect", "Landscape Arch", "Landscape"),    ("Irrigation Design", "[ABS] Landscape architect", "Landscape Arch", "Landscape"),    ("Maintenance Plan", "[ABS] Landscape architect", "Landscape Arch", "Landscape"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Daylighting Analysis---**Output:** Daylighting Analysis (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Daylighting Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Daylighting Analysis

# %%
# INPUT: Daylighting Analysisprint("=" * 70)print("INPUT: Daylighting Analysis")print("Output: DOMAIN 06 DESIGN - Daylighting Analysis")print("=" * 70)print("")inputs = [    ("Window Design", "[ABS] Architect proposes", "Architect", "Daylighting"),    ("Light Levels", "[ABS] Engineer calculates", "Engineer", "Daylighting"),    ("Shading Design", "[ABS] Architect proposes", "Architect", "Daylighting"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Daylighting"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

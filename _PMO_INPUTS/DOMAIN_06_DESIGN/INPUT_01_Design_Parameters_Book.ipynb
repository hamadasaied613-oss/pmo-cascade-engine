# %% [markdown]
# # INPUT: Design Parameters Book---**Output:** Design Parameters Book (Domain 06)**Standards:** RIBA Stage 2 | Design Brief**ISO:** ISO 21500:2012## PurposeConsolidate all design parameters from various disciplines.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Design Brief + Standards -> **THIS INPUT** -> **ACTIVITY:** Parameter Consolidation -> **OUTPUT:** Design Parameters Book

# %%
# INPUT: Design Parameters Bookprint("=" * 70)print("INPUT: Design Parameters Book")print("Output: Domain 06 - Design Parameters Book")print("=" * 70)print("")inputs = [    ("Architectural Parameters", "[REF] From Design Brief", "D01-INPUT_06", "Design Brief"),    ("Structural Parameters", "[ABS] Structural engineer", "Structural Eng", "Structural Concept"),    ("MEP Parameters", "[ABS] MEP engineer", "MEP Eng", "MEP Concept"),    ("Fire Safety Parameters", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Acoustic Parameters", "[ABS] Acoustic consultant", "Acoustic Consultant", "Acoustic Design"),    ("Landscape Parameters", "[ABS] Landscape architect", "Landscape Arch", "Landscape Design"),    ("Interior Parameters", "[ABS] Interior designer", "Interior Design", "Design Parameters"),    ("Sustainability Parameters", "[ABS] Sustainability consultant", "Sustainability", "Estidama Assessment"),    ("BIM Parameters", "[ABS] BIM manager", "BIM Manager", "BIM Management"),    ("Material Specifications", "[ABS] Materials engineer", "Materials Eng", "Materials Specification"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Parameters Matrix: AUTO-GENERATED")print("  - Conflict Resolution: CALCULATED")print("  - Integration Status: CALCULATED")

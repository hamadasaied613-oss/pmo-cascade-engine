# %% [markdown]
# # INPUT: Acoustic Design---**Output:** Acoustic Design (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Acoustic Design.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Acoustic Design

# %%
# INPUT: Acoustic Designprint("=" * 70)print("INPUT: Acoustic Design")print("Output: DOMAIN 06 DESIGN - Acoustic Design")print("=" * 70)print("")inputs = [    ("Acoustic Requirements", "[ABS] Client defines", "Client", "Acoustic Design"),    ("Noise Sources", "[ABS] Engineer identifies", "Engineer", "Acoustic Design"),    ("Mitigation Measures", "[ABS] Consultant proposes", "Consultant", "Acoustic Design"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Acoustic Design"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

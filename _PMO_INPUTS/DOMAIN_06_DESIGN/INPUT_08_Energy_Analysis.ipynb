# %% [markdown]
# # INPUT: Energy Analysis---**Output:** Energy Analysis (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Energy Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Energy Analysis

# %%
# INPUT: Energy Analysisprint("=" * 70)print("INPUT: Energy Analysis")print("Output: DOMAIN 06 DESIGN - Energy Analysis")print("=" * 70)print("")inputs = [    ("Energy Load", "[ABS] Engineer calculates", "Engineer", "Energy Analysis"),    ("System Efficiency", "[ABS] Engineer specifies", "Engineer", "Energy Analysis"),    ("Energy Target", "[ABS] Client defines", "Client", "Energy Analysis"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Energy Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Water Efficiency Design---**Output:** Water Efficiency Design (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Water Efficiency Design.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Water Efficiency Design

# %%
# INPUT: Water Efficiency Designprint("=" * 70)print("INPUT: Water Efficiency Design")print("Output: DOMAIN 06 DESIGN - Water Efficiency Design")print("=" * 70)print("")inputs = [    ("Water Fixtures", "[ABS] MEP engineer", "MEP Eng", "Water Efficiency"),    ("Irrigation Design", "[ABS] Landscape architect", "Landscape Arch", "Water Efficiency"),    ("Water Target", "[ABS] Sustainability target", "Sustainability", "Water Efficiency"),    ("Compliance Status", "[ABS] Consultant checks", "Consultant", "Water Efficiency"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

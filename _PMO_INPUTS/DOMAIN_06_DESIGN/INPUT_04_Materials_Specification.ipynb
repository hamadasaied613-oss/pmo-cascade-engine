# %% [markdown]
# # INPUT: Materials Specification---**Output:** Materials Specification (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Materials Specification.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Materials Specification

# %%
# INPUT: Materials Specificationprint("=" * 70)print("INPUT: Materials Specification")print("Output: DOMAIN 06 DESIGN - Materials Specification")print("=" * 70)print("")inputs = [    ("Material Types", "[ABS] Architect specifies", "Architect", "Materials"),    ("Performance Requirements", "[ABS] Engineer specifies", "Engineer", "Materials"),    ("Supplier Information", "[ABS] Supplier provides", "Supplier", "Materials"),    ("Quality Standards", "[ABS] Standards reference", "STD", "Materials"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

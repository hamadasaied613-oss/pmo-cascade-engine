# %% [markdown]
# # INPUT: Fire Safety Design---**Output:** Fire Safety Design (DOMAIN 06 DESIGN)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Fire Safety Design.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Fire Safety Design

# %%
# INPUT: Fire Safety Designprint("=" * 70)print("INPUT: Fire Safety Design")print("Output: DOMAIN 06 DESIGN - Fire Safety Design")print("=" * 70)print("")inputs = [    ("Fire Strategy", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Detection System", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Suppression System", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),    ("Evacuation Plan", "[ABS] Fire consultant", "Fire Consultant", "Fire Safety"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

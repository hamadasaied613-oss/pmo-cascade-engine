# %% [markdown]
# # INPUT: Structural Concept---**Output:** Structural Concept (Domain 06)**Standards:** ACI 318 | Eurocode 2 | BS 8110**ISO:** ISO 21500:2012## PurposeDefine structural system and design criteria.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Geotechnical Report + Building Program -> **THIS INPUT** -> **ACTIVITY:** Structural Design -> **OUTPUT:** Structural Concept

# %%
# INPUT: Structural Conceptprint("=" * 70)print("INPUT: Structural Concept")print("Output: Domain 06 - Structural Concept")print("=" * 70)print("")inputs = [    ("Geotechnical Report", "[REF] From Geotech", "D11-INPUT_01", "Geotechnical Report"),    ("Building Height", "[REF] From Zoning", "D04-INPUT_01", "Zoning Compliance"),    ("Number of Floors", "[ABS] Architect proposes", "Architect", "Design Parameters"),    ("Seismic Zone", "[REF] From Site Analysis", "D02-INPUT_01", "Site Analysis"),    ("Wind Load", "[ABS] Meteorological data", "STD-Met", "Structural Concept"),    ("Live Load", "[ABS] Building code", "STD-Code", "Structural Concept"),    ("Dead Load", "[ABS] Materials specification", "D06-INPUT_04", "Materials"),    ("Concrete Grade", "[ABS] Structural engineer", "Structural Eng", "Structural Concept"),    ("Steel Grade", "[ABS] Structural engineer", "Structural Eng", "Structural Concept"),    ("Foundation Type", "[ABS] Geotech recommendation", "D11-INPUT_01", "Foundation Design"),    ("Column Grid", "[ABS] Architect proposes", "Architect", "Design Parameters"),    ("Span Requirements", "[ABS] Architect proposes", "Architect", "Design Parameters"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Structural System: CALCULATED")print("  - Member Sizes: CALCULATED")print("  - Foundation Design: CALCULATED")

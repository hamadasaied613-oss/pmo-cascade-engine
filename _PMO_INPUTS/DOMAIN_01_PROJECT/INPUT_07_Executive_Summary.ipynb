# %% [markdown]
# # INPUT: Executive Summary---**Output:** Executive Summary (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Executive Summary.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Executive Summary

# %%
# INPUT: Executive Summaryprint("=" * 70)print("INPUT: Executive Summary")print("Output: DOMAIN 01 PROJECT - Executive Summary")print("=" * 70)print("")inputs = [    ("Project Overview", "[REF] From all domains", "All Domains", "Executive Summary"),    ("Key Metrics", "[REF] From KPIs", "Calculation", "Executive Summary"),    ("Status Summary", "[REF] From Progress", "Progress Tracker", "Executive Summary"),    ("Risk Summary", "[REF] From Risk Register", "D01-INPUT_04", "Risk Register"),    ("Financial Summary", "[REF] From Cost", "D08-INPUT_02", "Cost Estimate"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

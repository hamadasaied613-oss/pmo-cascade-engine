# %% [markdown]
# # INPUT: Plot Analysis---**Output:** Plot Analysis (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Plot Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Plot Analysis

# %%
# INPUT: Plot Analysisprint("=" * 70)print("INPUT: Plot Analysis")print("Output: DOMAIN 01 PROJECT - Plot Analysis")print("=" * 70)print("")inputs = [    ("Plot Number", "[REF] From Client Brief", "D01-INPUT_05", "Client Brief"),    ("Plot Dimensions", "[ABS] Survey", "Surveyor", "Plot Analysis"),    ("Plot Topography", "[ABS] Survey", "Surveyor", "Plot Analysis"),    ("Plot Constraints", "[ABS] Site analysis", "D02-INPUT_01", "Site Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

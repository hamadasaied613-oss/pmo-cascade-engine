# %% [markdown]
# # مدخل: ميثاق المشروع (Project Charter)---**المخرج المقابل:** ميثاق المشروع - Domain 01**المعايير:** PMI-PMBOK الفصل 4.1 | ISO 21500**الجهة المعتمدة:** هيئة البناء والأسكان## الغرضتحديد تفويض المشروع ونطاقه paźراً والقيود والاضطرارات.## رمزية المصادر| الرمز | المعنى ||--------|---------|| **[مطلق]** | بيانات مطلقة || **[مرجعي]** | مرجعية من وثيقة سابقة || **[مشتق]** | مُشتق من مدخلات أخرى || **[معياري]** | قيمة معيارية || **[نتيجة]** | مخرج من نشاط سابق |## المسار**مدخلات:** بريفيه العميل + دراسة الجدوى → **هذا المدخل** → **عملية:** إعداد الميثاق → **مخرج:** ميثاق المشروع

# %%
# مدخل: ميثاق المشروعprint("=" * 70)print("مدخل: ميثاق المشروع (Project Charter)")print("المخرج المقابل: Domain 01 - ميثاق المشروع")print("=" * 70)print("")inputs = [    ("اسم المشروع", "[مرجعي] من بريفيه العميل", "مدخل_01", "بريفيه العميل"),    ("مدير المشروع", "[مطلق] التكليف من الإدارة", "الإدارة", "سجل أصحاب المصلحة"),    ("الراعي (Sponsor)", "[مطلق] العميل يحدد", "العميل", "سجل أصحاب المصلحة"),    ("حالة العمل (Business Case)", "[مرجعي] من دراسة الجدوى", "مدخل_03", "دراسة الجدوى"),    ("النطاق التفصيلي", "[مطلق] العميل + مدير المشروع", "العميل", "معايرات التصميم"),    ("المخرجات الرئيسية", "[مطلق] مدير المشروع يحدد", "مدير المشروع", "البرنامج الرئيسي"),    ("المراحل الرئيسية", "[مشتق] من البرنامج الرئيسي", "نتيجة_الجدول الزمني", "البرنامج الرئيسي"),    ("الميزانية (نطاق عالي)", "[مرجعي] من بريفيه العميل", "مدخل_01", "بريفيه العميل"),    ("الجدول الزمني (نطاق عالي)", "[مطلق] العميل يحدد", "العميل", "البرنامج الرئيسي"),    ("القيود", "[مطلق] العميل + مدير المشروع", "العميل", "سجل المخاطر"),    ("الاضطرارات", "[مطلق] العميل + مدير المشروع", "العميل", "سجل المخاطر"),    ("معايير النجاح", "[مطلق] العميل يحدد", "العميل", "تحليل الجدوى"),    ("مستوى الصلاحيات", "[مطلق] العميل يحدد", "العميل", "مصفوفة RACI"),    (" tolerated риск التحمل", "[مطلق] العميل يحدد", "العميل", "سجل المخاطر"),    ("التحكم بالتغييرات", "[معياري] عملية PMI", "معياري", "إدارة التغيير"),    ("الموافقات المطلوبة", "[مطلق] العميل يحدد", "العميل", "مصفوفة الجهات"),]print("حقل الإدخال                       المصدر                          من أين            إلى أين")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<30} {inp[2]:<18} {inp[3]}")print("")print("=" * 70)print("حقول المخرج (تلقائي):")print("  - رقم الميثاق: تلقائي")print("  - تاريخ الموافقة: تاريخ التوقيع")print("  - الإصدار: 1.0")print("  - الحالة: بانتظار الموافقة")print("=" * 70)

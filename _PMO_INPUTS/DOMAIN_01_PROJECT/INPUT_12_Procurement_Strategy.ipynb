# %% [markdown]
# # INPUT: Procurement Strategy---**Output:** Procurement Strategy (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Procurement Strategy.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Procurement Strategy

# %%
# INPUT: Procurement Strategyprint("=" * 70)print("INPUT: Procurement Strategy")print("Output: DOMAIN 01 PROJECT - Procurement Strategy")print("=" * 70)print("")inputs = [    ("Project Requirements", "[REF] From Scope", "D01-INPUT_02", "Project Charter"),    ("Market Conditions", "[ABS] Market research", "Consultant", "Market Analysis"),    ("Risk Allocation", "[ABS] PM defines", "PM", "Procurement Strategy"),    ("Contract Form", "[ABS] Client preference", "Client", "Procurement Strategy"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

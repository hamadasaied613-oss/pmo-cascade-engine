# %% [markdown]
# # INPUT: Change Management---**Output:** Change Management (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Change Management.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Change Management

# %%
# INPUT: Change Managementprint("=" * 70)print("INPUT: Change Management")print("Output: DOMAIN 01 PROJECT - Change Management")print("=" * 70)print("")inputs = [    ("Change Request", "[ABS] Team submits", "Team", "Change Management"),    ("Impact Assessment", "[ABS] PM evaluates", "PM", "Change Management"),    ("Approval Status", "[ABS] Client approves", "Client", "Change Management"),    ("Implementation Plan", "[ABS] PM defines", "PM", "Change Management"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

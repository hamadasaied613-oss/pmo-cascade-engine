# %% [markdown]
# # INPUT: Benchmarking Report---**Output:** Benchmarking Report (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Benchmarking Report.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Benchmarking Report

# %%
# INPUT: Benchmarking Reportprint("=" * 70)print("INPUT: Benchmarking Report")print("Output: DOMAIN 01 PROJECT - Benchmarking Report")print("=" * 70)print("")inputs = [    ("Comparable Projects", "[ABS] Research", "Consultant", "Benchmarking"),    ("Industry Averages", "[ABS] Market data", "Market", "Benchmarking"),    ("Performance Metrics", "[ABS] Team defines", "Team", "Benchmarking"),    ("Best Practices", "[ABS] Industry research", "Industry", "Benchmarking"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

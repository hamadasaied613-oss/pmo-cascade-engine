# %% [markdown]
# # INPUT: Business Case---**Output:** Business Case (DOMAIN 01 PROJECT)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Business Case.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Business Case

# %%
# INPUT: Business Caseprint("=" * 70)print("INPUT: Business Case")print("Output: DOMAIN 01 PROJECT - Business Case")print("=" * 70)print("")inputs = [    ("Investment Required", "[ABS] Client provides", "Client", "Financial Feasibility"),    ("Expected Returns", "[ABS] Client provides", "Client", "Financial Feasibility"),    ("Market Opportunity", "[ABS] Market research", "Consultant", "Market Analysis"),    ("Strategic Alignment", "[ABS] Client defines", "Client", "Project Charter"),    ("Risk Assessment", "[REF] From Risk Register", "D01-INPUT_04", "Risk Register"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

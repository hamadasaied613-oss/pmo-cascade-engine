# %% [markdown]
# # مدخل: سجل المخاطر (Risk Register)---**المخرج المقابل:** سجل المخاطر - Domain 01**المعايير:** PMI-PMBOK الفصل 11 | ISO 31000:2018**الجهة المعتمدة:** هيئة البناء والأسكان## الغرضتحديد وتقييم وتخطيط الاستجابة لمخاطر المشروع.## رمزية المصادر| الرمز | المعنى ||--------|---------|| **[مطلق]** | بيانات مطلقة || **[مرجعي]** | مرجعية من وثيقة سابقة || **[مشتق]** | مُشتق من مدخلات أخرى || **[معياري]** | قيمة معيارية || **[نتيجة]** | مخرج من نشاط سابق |## المسار**مدخلات:** بريفيه العميل + دراسة الجدوى + ميثاق المشروع → **هذا المدخل** → **عملية:** تحليل المخاطر → **مخرج:** سجل المخاطر

# %%
# مدخل: سجل المخاطرprint("=" * 70)print("مدخل: سجل المخاطر (Risk Register)")print("المخرج المقابل: Domain 01 - سجل المخاطر")print("=" * 70)print("")inputs = [    ("رقم المخاطرة", "[مشتق] تلقائي", "النظام", "سجل المخاطر"),    ("وصف المخاطرة", "[مطلق] الفريق يحددها", "الفريق", "سجل المخاطر"),    ("فئة المخاطرة", "[مطلق] الفريق يصنفها", "الفريق", "سجل المخاطر"),    ("الاحتمالية (1-5)", "[مطلق] الفريق يقدرها", "الفريق", "سجل المخاطر"),    ("التأثير (1-5)", "[مطلق] الفريق يقدرها", "الفريق", "سجل المخاطر"),    ("درجة المخاطرة", "[مشتق] الاحتمالية x التأثير", "محسوب", "سجل المخاطرة"),    ("مالك المخاطرة", "[مطلق] مدير المشروع يعيّنه", "مدير المشروع", "سجل المخاطر"),    ("استراتيجية الاستجابة", "[مطلق] الفريق يقرر", "الفريق", "سجل المخاطر"),    ("إجراءات التخفيف", "[مطلق] الفريق يحدد", "الفريق", "سجل المخاطر"),    ("الميزانية التحفظية", "[مشتق] من درجة المخاطرة", "محسوب", "ميزانية التحفظ"),    ("أحداث الزناد", "[مطلق] الفريق يحددها", "الفريق", "سجل المخاطر"),    ("الحالة", "[معياري] مفتوحة", "معياري", "سجل المخاطر"),    ("الدروس المستفادة", "[نتيجة] من مشاريع سابقة", "نتيجة_تاريخية", "سجل المخاطر"),    ("العوامل الخارجية", "[مطلق] تحليل البيئة", "الفريق", "سجل المخاطر"),    ("التداعيات المالية", "[مشتق] من التأثير المالي", "محسوب", "ميزانية التحفظ"),]print("حقل الإدخال                       المصدر                          من أين            إلى أين")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<30} {inp[2]:<18} {inp[3]}")print("")print("=" * 70)print("قواعد التحقق:")print("  - الاحتمالية: 1 (نادرة) إلى 5 (أكيدة تقريباً)")print("  - التأثير: 1 (ضئيل) إلى 5 (كارثي)")print("  - درجة المخاطرة = الاحتمالية x التأثير")print("  - المخاطر العالية (>=15) تتطلب استجابة فورية")print("=" * 70)

# %% [markdown]
# # INPUT: Unit Mix Optimization---**Output:** Unit Mix Optimization (Domain 07)**Standards:** Market Analysis | Revenue Optimization**ISO:** ISO 21500:2012## PurposeOptimize unit mix for maximum revenue.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Market Analysis + Building Program -> **THIS INPUT** -> **ACTIVITY:** Unit Mix Optimization -> **OUTPUT:** Unit Mix Optimization

# %%
# INPUT: Unit Mix Optimizationprint("=" * 70)print("INPUT: Unit Mix Optimization")print("Output: Domain 07 - Unit Mix Optimization")print("=" * 70)print("")inputs = [    ("Market Demand Data", "[ABS] Market research", "Market Research", "Market Analysis"),    ("Target Demographics", "[ABS] Client defines", "Client", "Market Analysis"),    ("Available GFA (m2)", "[REF] From FAR Analysis", "D04-INPUT_02", "FAR Analysis"),    ("Unit Type Distribution", "[ABS] Architect proposes", "Architect", "Unit Mix"),    ("Unit Sizes (m2)", "[ABS] Architect proposes", "Architect", "Unit Mix"),    ("Price per m2 (AED)", "[ABS] Market data", "Market Research", "Revenue Projection"),    ("Parking Allocation", "[ABS] Parking analysis", "D04-INPUT_03", "Parking Analysis"),    ("Amenity Space (m2)", "[ABS] Client requirement", "Client", "Space Program"),    ("Common Area (m2)", "[ABS] Architect proposes", "Architect", "Unit Mix"),    ("Revenue Target (AED)", "[ABS] Client defines", "Client", "Financial Feasibility"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Optimal Unit Mix: CALCULATED")print("  - Revenue Projection: CALCULATED")print("  - Absorption Rate: CALCULATED")

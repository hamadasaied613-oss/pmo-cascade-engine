# %% [markdown]
# # INPUT: Revenue Projection---**Output:** Revenue Projection (Domain 07)**Standards:** Financial Analysis**ISO:** ISO 21500:2012## PurposeProject revenue from unit sales and leasing.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Unit Mix + Market Prices -> **THIS INPUT** -> **ACTIVITY:** Revenue Calculation -> **OUTPUT:** Revenue Projection

# %%
# INPUT: Revenue Projectionprint("=" * 70)print("INPUT: Revenue Projection")print("Output: Domain 07 - Revenue Projection")print("=" * 70)print("")inputs = [    ("Unit Types", "[REF] From Unit Mix", "D07-INPUT_01", "Unit Mix"),    ("Unit Quantities", "[REF] From Unit Mix", "D07-INPUT_01", "Unit Mix"),    ("Unit Areas (m2)", "[REF] From Unit Mix", "D07-INPUT_01", "Unit Mix"),    ("Price per m2 (AED)", "[ABS] Market research", "Market Research", "Market Analysis"),    ("Payment Plan Terms", "[ABS] Client defines", "Client", "Financial Feasibility"),    ("Lease Rate (AED/m2/year)", "[ABS] Market data", "Market Research", "Market Analysis"),    ("Occupancy Rate (%)", "[ABS] Market assumption", "Market Research", "Market Analysis"),    ("Annual Escalation (%)", "[ABS] Market assumption", "Market Research", "Market Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Total Sales Revenue: CALCULATED")print("  - Total Lease Revenue: CALCULATED")print("  - NPV of Revenue: CALCULATED")

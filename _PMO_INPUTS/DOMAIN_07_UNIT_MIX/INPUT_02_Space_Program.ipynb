# %% [markdown]
# # INPUT: Space Program---**Output:** Space Program (Domain 07)**Standards:** Architectural Programming**ISO:** ISO 21500:2012## PurposeDefine space requirements for all building functions.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Client Brief + Building Code -> **THIS INPUT** -> **ACTIVITY:** Space Programming -> **OUTPUT:** Space Program

# %%
# INPUT: Space Programprint("=" * 70)print("INPUT: Space Program")print("Output: Domain 07 - Space Program")print("=" * 70)print("")inputs = [    ("Residential Units (m2)", "[ABS] Architect calculates", "Architect", "Space Program"),    ("Commercial Space (m2)", "[ABS] Architect calculates", "Architect", "Space Program"),    ("Parking Area (m2)", "[ABS] Parking analysis", "D04-INPUT_03", "Parking Analysis"),    ("Lobby Area (m2)", "[ABS] Architect proposes", "Architect", "Space Program"),    ("MEP Rooms (m2)", "[ABS] MEP engineer", "MEP Eng", "MEP Concept"),    ("Staircase Area (m2)", "[ABS] Fire code requirement", "STD-FireCode", "Fire Safety"),    ("Lift Lobby (m2)", "[ABS] Architect proposes", "Architect", "Space Program"),    ("Refuse Room (m2)", "[ABS] Municipality requirement", "ACT-Municipality", "Waste Management"),    ("Generator Room (m2)", "[ABS] MEP engineer", "MEP Eng", "MEP Concept"),    ("Water Tank Room (m2)", "[ABS] MEP engineer", "MEP Eng", "MEP Concept"),    ("Amenity Space (m2)", "[ABS] Client requirement", "Client", "Space Program"),    ("Common Area (m2)", "[ABS] Architect proposes", "Architect", "Space Program"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Total GFA: CALCULATED")print("  - Efficiency Ratio: CALCULATED")print("  - Space Distribution: CALCULATED")

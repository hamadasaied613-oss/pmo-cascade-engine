# %% [markdown]
# # INPUT: Stacking Plan---**Output:** Stacking Plan (DOMAIN 07 UNIT MIX)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Stacking Plan.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Stacking Plan

# %%
# INPUT: Stacking Planprint("=" * 70)print("INPUT: Stacking Plan")print("Output: DOMAIN 07 UNIT MIX - Stacking Plan")print("=" * 70)print("")inputs = [    ("Floor Layout", "[ABS] Architect proposes", "Architect", "Stacking Plan"),    ("Unit Distribution", "[ABS] Architect proposes", "Architect", "Stacking Plan"),    ("Amenity Location", "[ABS] Architect proposes", "Architect", "Stacking Plan"),    ("Common Areas", "[ABS] Architect proposes", "Architect", "Stacking Plan"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

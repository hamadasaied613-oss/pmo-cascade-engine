# %% [markdown]
# # INPUT: Market Analysis---**Output:** Market Analysis (DOMAIN 07 UNIT MIX)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Market Analysis.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Market Analysis

# %%
# INPUT: Market Analysisprint("=" * 70)print("INPUT: Market Analysis")print("Output: DOMAIN 07 UNIT MIX - Market Analysis")print("=" * 70)print("")inputs = [    ("Market Data", "[ABS] Market research", "Market Research", "Market Analysis"),    ("Competitor Analysis", "[ABS] Market research", "Market Research", "Market Analysis"),    ("Demand Forecast", "[ABS] Market research", "Market Research", "Market Analysis"),    ("Pricing Strategy", "[ABS] Client defines", "Client", "Market Analysis"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

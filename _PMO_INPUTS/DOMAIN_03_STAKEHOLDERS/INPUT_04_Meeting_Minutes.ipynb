# %% [markdown]
# # INPUT: Meeting Minutes---**Output:** Meeting Minutes (DOMAIN 03 STAKEHOLDERS)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Meeting Minutes.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Meeting Minutes

# %%
# INPUT: Meeting Minutesprint("=" * 70)print("INPUT: Meeting Minutes")print("Output: DOMAIN 03 STAKEHOLDERS - Meeting Minutes")print("=" * 70)print("")inputs = [    ("Meeting Date", "[ABS] Record", "PM", "Meeting Minutes"),    ("Attendees", "[ABS] Record", "PM", "Meeting Minutes"),    ("Discussion Points", "[ABS] Record", "PM", "Meeting Minutes"),    ("Action Items", "[ABS] Record", "PM", "Meeting Minutes"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

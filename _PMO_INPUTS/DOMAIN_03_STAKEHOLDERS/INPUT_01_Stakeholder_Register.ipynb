# %% [markdown]
# # INPUT: Stakeholder Register---**Output:** Stakeholder Register (Domain 03)**Standards:** PMI-PMBOK Section 13.1**ISO:** ISO 21500:2012## PurposeIdentify and classify all project stakeholders.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Client Brief + Project Charter -> **THIS INPUT** -> **ACTIVITY:** Stakeholder Analysis -> **OUTPUT:** Stakeholder Register

# %%
# INPUT: Stakeholder Registerprint("=" * 70)print("INPUT: Stakeholder Register")print("Output: Domain 03 - Stakeholder Register")print("=" * 70)print("")inputs = [    ("Stakeholder Name", "[ABS] Team identifies", "Team", "Stakeholder Register"),    ("Organization", "[ABS] Team identifies", "Team", "Stakeholder Register"),    ("Role/Position", "[ABS] Team identifies", "Team", "Stakeholder Register"),    ("Contact Information", "[ABS] Team collects", "Team", "Stakeholder Register"),    ("Interest Level (1-5)", "[ABS] Team assesses", "Team", "Stakeholder Register"),    ("Influence Level (1-5)", "[ABS] Team assesses", "Team", "Stakeholder Register"),    ("Attitude", "[ABS] Team assesses", "Team", "Stakeholder Register"),    ("Communication Needs", "[ABS] Team identifies", "Team", "Communication Plan"),    ("Information Requirements", "[ABS] Team identifies", "Team", "Communication Plan"),    ("Engagement Strategy", "[ABS] PM decides", "PM", "Stakeholder Register"),    ("Power/Interest Grid Position", "[DER] From Power/Interest", "DERIVED", "Stakeholder Register"),    ("Risk Level", "[DER] From Influence/Attitude", "DERIVED", "Risk Register"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Power/Interest Grid: CALCULATED")print("  - Engagement Priority: CALCULATED")print("  - Communication Frequency: CALCULATED")

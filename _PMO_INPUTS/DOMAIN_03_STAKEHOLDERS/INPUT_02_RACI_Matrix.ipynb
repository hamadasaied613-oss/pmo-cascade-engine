# %% [markdown]
# # INPUT: RACI Matrix---**Output:** RACI Matrix (Domain 03)**Standards:** PMI-PMBOK Responsibility Assignment**ISO:** ISO 21500:2012## PurposeDefine Responsible, Accountable, Consulted, Informed roles.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Stakeholder Register + Project Charter -> **THIS INPUT** -> **ACTIVITY:** RACI Assignment -> **OUTPUT:** RACI Matrix

# %%
# INPUT: RACI Matrixprint("=" * 70)print("INPUT: RACI Matrix")print("Output: Domain 03 - RACI Matrix")print("=" * 70)print("")inputs = [    ("Activity/Deliverable", "[ABS] PM defines", "PM", "Master Program"),    ("Responsible (R)", "[ABS] PM assigns", "PM", "RACI Matrix"),    ("Accountable (A)", "[ABS] PM assigns", "PM", "RACI Matrix"),    ("Consulted (C)", "[ABS] PM assigns", "PM", "RACI Matrix"),    ("Informed (I)", "[ABS] PM assigns", "PM", "RACI Matrix"),    ("Stakeholder Name", "[REF] From Stakeholder Reg", "D03-INPUT_01", "Stakeholder Register"),    ("Role", "[REF] From Stakeholder Reg", "D03-INPUT_01", "Stakeholder Register"),    ("Authority Level", "[ABS] Client defines", "Client", "Project Charter"),    ("Escalation Path", "[ABS] PM defines", "PM", "Escalation Procedure"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - RACI Conflict Check: CALCULATED")print("  - Responsibility Coverage: CALCULATED")

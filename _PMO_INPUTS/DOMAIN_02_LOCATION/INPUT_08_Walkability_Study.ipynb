# %% [markdown]
# # INPUT: Walkability Study---**Output:** Walkability Study (DOMAIN 02 LOCATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Walkability Study.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Walkability Study

# %%
# INPUT: Walkability Studyprint("=" * 70)print("INPUT: Walkability Study")print("Output: DOMAIN 02 LOCATION - Walkability Study")print("=" * 70)print("")inputs = [    ("Pedestrian Routes", "[ABS] Site survey", "Site Visit", "Walkability"),    ("Accessibility Features", "[ABS] Site survey", "Site Visit", "Walkability"),    ("Safety Features", "[ABS] Site survey", "Site Visit", "Walkability"),    ("Amenity Proximity", "[ABS] Map research", "GIS", "Walkability"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Utilities Mapping---**Output:** Utilities Mapping (DOMAIN 02 LOCATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Utilities Mapping.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Utilities Mapping

# %%
# INPUT: Utilities Mappingprint("=" * 70)print("INPUT: Utilities Mapping")print("Output: DOMAIN 02 LOCATION - Utilities Mapping")print("=" * 70)print("")inputs = [    ("Water Supply", "[ABS] Utility data", "Water Authority", "Utilities"),    ("Electricity Supply", "[ABS] Utility data", "Electricity Authority", "Utilities"),    ("Gas Supply", "[ABS] Utility data", "Gas Authority", "Utilities"),    ("Telecom Network", "[ABS] Utility data", "Telecom Authority", "Utilities"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Infrastructure Assessment---**Output:** Infrastructure Assessment (DOMAIN 02 LOCATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Infrastructure Assessment.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Infrastructure Assessment

# %%
# INPUT: Infrastructure Assessmentprint("=" * 70)print("INPUT: Infrastructure Assessment")print("Output: DOMAIN 02 LOCATION - Infrastructure Assessment")print("=" * 70)print("")inputs = [    ("Road Network", "[ABS] Government data", "Government", "Infrastructure"),    ("Utility Capacity", "[ABS] Utility survey", "Utilities", "Infrastructure"),    ("Transport Links", "[ABS] Transport data", "Transport", "Infrastructure"),    ("Digital Infrastructure", "[ABS] Telecom data", "Telecom", "Infrastructure"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

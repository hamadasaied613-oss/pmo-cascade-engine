# %% [markdown]
# # INPUT: Emirate Comparison---**Output:** Emirate Comparison (DOMAIN 02 LOCATION)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Emirate Comparison.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Emirate Comparison

# %%
# INPUT: Emirate Comparisonprint("=" * 70)print("INPUT: Emirate Comparison")print("Output: DOMAIN 02 LOCATION - Emirate Comparison")print("=" * 70)print("")inputs = [    ("Emirate Data", "[ABS] Research", "Consultant", "Emirate Comparison"),    ("Regulatory Differences", "[ABS] Legal research", "Legal", "Emirate Comparison"),    ("Cost Variations", "[ABS] Market data", "Market", "Emirate Comparison"),    ("Infrastructure Status", "[ABS] Government data", "Government", "Emirate Comparison"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Variation Order---**Output:** Variation Order (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Variation Order.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Variation Order

# %%
# INPUT: Variation Orderprint("=" * 70)print("INPUT: Variation Order")print("Output: DOMAIN 08 COST - Variation Order")print("=" * 70)print("")inputs = [    ("Variation Description", "[ABS] Contractor submits", "Contractor", "Variation Order"),    ("Cost Impact", "[ABS] QS calculates", "QS", "Variation Order"),    ("Time Impact", "[ABS] PM evaluates", "PM", "Variation Order"),    ("Approval Status", "[ABS] Client approves", "Client", "Variation Order"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

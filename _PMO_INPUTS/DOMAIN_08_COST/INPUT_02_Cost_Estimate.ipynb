# %% [markdown]
# # INPUT: Cost Estimate---**Output:** Cost Estimate (Domain 08)**Standards:** QS Practice | Cost Planning**ISO:** ISO 20400:2017## PurposeEstimate total project cost.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** BOQ + Market Rates -> **THIS INPUT** -> **ACTIVITY:** Cost Estimation -> **OUTPUT:** Cost Estimate

# %%
# INPUT: Cost Estimateprint("=" * 70)print("INPUT: Cost Estimate")print("Output: Domain 08 - Cost Estimate")print("=" * 70)print("")inputs = [    ("Construction Cost (AED/m2)", "[ABS] Market data", "Market Rates", "Cost Estimate"),    ("Land Cost (AED)", "[ABS] Client/DLD", "Client/DLD", "Financial Feasibility"),    ("Consultancy Fees (%)", "[ABS] Market rates", "Market Rates", "Cost Estimate"),    ("Authority Fees (AED)", "[ABS] Municipality schedule", "ACT-Municipality", "Permit Tracker"),    ("Contingency (%)", "[ABS] Risk assessment", "Risk Assessment", "Risk Budget"),    ("Inflation Rate (%)", "[ABS] Economic forecast", "STD-Economic", "Cash Flow"),    ("Financing Cost (%)", "[ABS] Bank terms", "Bank", "Financial Feasibility"),    ("Developer Profit (%)", "[ABS] Client target", "Client", "Financial Feasibility"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Total Project Cost: CALCULATED")print("  - Cost per m2: CALCULATED")print("  - Cost Breakdown: CALCULATED")

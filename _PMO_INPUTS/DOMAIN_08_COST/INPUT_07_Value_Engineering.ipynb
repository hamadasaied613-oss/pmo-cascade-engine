# %% [markdown]
# # INPUT: Value Engineering---**Output:** Value Engineering (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Value Engineering.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Value Engineering

# %%
# INPUT: Value Engineeringprint("=" * 70)print("INPUT: Value Engineering")print("Output: DOMAIN 08 COST - Value Engineering")print("=" * 70)print("")inputs = [    ("Current Design", "[REF] From Design", "D06-INPUT_01", "Design Parameters"),    ("Alternative Proposals", "[ABS] Team proposes", "Team", "Value Engineering"),    ("Cost Comparison", "[ABS] QS compares", "QS", "Value Engineering"),    ("Recommendation", "[ABS] Team recommends", "Team", "Value Engineering"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

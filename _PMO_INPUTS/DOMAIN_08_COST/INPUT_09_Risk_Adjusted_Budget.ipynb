# %% [markdown]
# # INPUT: Risk Adjusted Budget---**Output:** Risk Adjusted Budget (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Risk Adjusted Budget.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Risk Adjusted Budget

# %%
# INPUT: Risk Adjusted Budgetprint("=" * 70)print("INPUT: Risk Adjusted Budget")print("Output: DOMAIN 08 COST - Risk Adjusted Budget")print("=" * 70)print("")inputs = [    ("Base Cost", "[REF] From Cost Estimate", "D08-INPUT_02", "Cost Estimate"),    ("Risk Contingency", "[REF] From Risk Register", "D01-INPUT_04", "Risk Register"),    ("Management Reserve", "[ABS] Client defines", "Client", "Risk Adjusted Budget"),    ("Inflation Allowance", "[ABS] Economic data", "Economic", "Risk Adjusted Budget"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Bill of Quantities---**Output:** Bill of Quantities (Domain 08)**Standards:** CESMM4 | POMI | NRM**ISO:** ISO 12006:2015## PurposePrepare detailed bill of quantities for tender.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Design Drawings + Specifications -> **THIS INPUT** -> **ACTIVITY:** Quantity Takeoff -> **OUTPUT:** Bill of Quantities

# %%
# INPUT: Bill of Quantitiesprint("=" * 70)print("INPUT: Bill of Quantities")print("Output: Domain 08 - Bill of Quantities")print("=" * 70)print("")inputs = [    ("Architectural Drawings", "[REF] From Design", "D06-INPUT_01", "Design Parameters"),    ("Structural Drawings", "[REF] From Structural", "D06-INPUT_02", "Structural Concept"),    ("MEP Drawings", "[REF] From MEP", "D06-INPUT_03", "MEP Concept"),    ("Specifications", "[ABS] Specifications document", "Specifications", "Materials"),    ("Measurement Method", "[ABS] CESMM4/POMI", "STD", "BOQ"),    ("Rate Analysis", "[ABS] Market rates", "Market Rates", "Cost Estimate"),    ("Preliminaries (%)", "[ABS] Contractor input", "Contractor", "BOQ"),    ("Contingency (%)", "[ABS] Risk assessment", "Risk Assessment", "Risk Budget"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Bill Amount: CALCULATED")print("  - Unit Rates: CALCULATED")print("  - Total Quantities: CALCULATED")

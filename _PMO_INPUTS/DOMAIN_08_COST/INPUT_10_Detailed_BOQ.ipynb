# %% [markdown]
# # INPUT: Detailed BOQ---**Output:** Detailed BOQ (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Detailed BOQ.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Detailed BOQ

# %%
# INPUT: Detailed BOQprint("=" * 70)print("INPUT: Detailed BOQ")print("Output: DOMAIN 08 COST - Detailed BOQ")print("=" * 70)print("")inputs = [    ("Bill A Preliminaries", "[REF] From BOQ", "D08-INPUT_01", "BOQ"),    ("Bill B Substructure", "[REF] From BOQ", "D08-INPUT_01", "BOQ"),    ("Bill C Superstructure", "[REF] From BOQ", "D08-INPUT_01", "BOQ"),    ("Bill D Finishes", "[REF] From BOQ", "D08-INPUT_01", "BOQ"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

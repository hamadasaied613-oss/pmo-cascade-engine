# %% [markdown]
# # INPUT: Procurement Strategy---**Output:** Procurement Strategy (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Procurement Strategy.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Procurement Strategy

# %%
# INPUT: Procurement Strategyprint("=" * 70)print("INPUT: Procurement Strategy")print("Output: DOMAIN 08 COST - Procurement Strategy")print("=" * 70)print("")inputs = [    ("Package Definition", "[ABS] PM defines", "PM", "Procurement Strategy"),    ("Tender Strategy", "[ABS] PM defines", "PM", "Procurement Strategy"),    ("Contract Strategy", "[ABS] PM defines", "PM", "Procurement Strategy"),    ("Risk Allocation", "[ABS] PM defines", "PM", "Procurement Strategy"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Financial Feasibility---**Output:** Financial Feasibility (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Financial Feasibility.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Financial Feasibility

# %%
# INPUT: Financial Feasibilityprint("=" * 70)print("INPUT: Financial Feasibility")print("Output: DOMAIN 08 COST - Financial Feasibility")print("=" * 70)print("")inputs = [    ("Revenue Projection", "[REF] From Revenue", "D07-INPUT_03", "Revenue Projection"),    ("Cost Projection", "[REF] From Cost", "D08-INPUT_02", "Cost Estimate"),    ("Financing Terms", "[ABS] Bank terms", "Bank", "Financial Feasibility"),    ("Return Metrics", "[ABS] Client defines", "Client", "Financial Feasibility"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")

# %% [markdown]
# # INPUT: Cash Flow---**Output:** Cash Flow (Domain 08)**Standards:** Financial Modeling**ISO:** ISO 20400:2017## PurposeProject cash flow over project duration.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Cost Estimate + Payment Terms -> **THIS INPUT** -> **ACTIVITY:** Cash Flow Analysis -> **OUTPUT:** Cash Flow

# %%
# INPUT: Cash Flowprint("=" * 70)print("INPUT: Cash Flow")print("Output: Domain 08 - Cash Flow")print("=" * 70)print("")inputs = [    ("Total Project Cost", "[REF] From Cost Estimate", "D08-INPUT_02", "Cost Estimate"),    ("Construction Duration", "[REF] From Master Program", "D09-INPUT_01", "Master Program"),    ("Payment Milestones", "[ABS] Contract terms", "Contract", "Contract Admin"),    ("Client Payment Terms", "[ABS] Sales contract", "Sales Contract", "Revenue"),    ("Inflation Assumption", "[ABS] Economic forecast", "STD-Economic", "Cash Flow"),    ("Financing Drawdown", "[ABS] Bank facility", "Bank", "Financial Feasibility"),    ("Retention Terms (%)", "[ABS] Contract terms", "Contract", "Contract Admin"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Monthly Cash Flow: CALCULATED")print("  - Cumulative Cash Flow: CALCULATED")print("  - Peak Cash Requirement: CALCULATED")

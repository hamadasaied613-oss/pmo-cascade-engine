# %% [markdown]
# # INPUT: Life Cycle Cost---**Output:** Life Cycle Cost (DOMAIN 08 COST)**Standards:** Professional Engineering Standards**ISO:** ISO 21500:2012## PurposeCollect all required data for Life Cycle Cost.## Flow: INPUT -> ACTIVITY -> OUTPUT**INPUT:** Related Domain Data -> **THIS INPUT** -> **ACTIVITY:** Processing -> **OUTPUT:** Life Cycle Cost

# %%
# INPUT: Life Cycle Costprint("=" * 70)print("INPUT: Life Cycle Cost")print("Output: DOMAIN 08 COST - Life Cycle Cost")print("=" * 70)print("")inputs = [    ("Initial Cost", "[REF] From Cost Estimate", "D08-INPUT_02", "Cost Estimate"),    ("Maintenance Cost", "[ABS] Estimate", "Consultant", "Life Cycle Cost"),    ("Energy Cost", "[ABS] Estimate", "MEP Eng", "Life Cycle Cost"),    ("Replacement Cost", "[ABS] Estimate", "Consultant", "Life Cycle Cost"),]print("Field                              Source                       Where From       Feeds To")print("-" * 95)for inp in inputs:    print(f"  {inp[0]:<35} {inp[1]:<27} {inp[2]:<17} {inp[3]}")print("")print("Output Fields (auto-populated):")print("  - Status: CALCULATED")print("  - Reference Number: AUTO-GENERATED")
